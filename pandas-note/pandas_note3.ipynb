# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/ML_AI/DATASETS/survey_results_public.csv")
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
data_schema = pd.read_csv("/content/drive/MyDrive/ML_AI/DATASETS/survey_results_schema.csv", index_col = "Column")
data_schema
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
filt_nepal = data['Country'] == 'Nepal'

data.loc[filt_nepal]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %% [markdown]
# **assignment**

# %%
data_schema.loc['WelcomeChange']
# Out:
# QuestionText    Compared to last year, how welcome do you feel...
# Name: WelcomeChange, dtype: object

# %%
data_schema.loc['WelcomeChange', 'QuestionText']
# Out:
# 'Compared to last year, how welcome do you feel on Stack Overflow?'

# %%
data['WelcomeChange'].value_counts()
# Out:
# Just as welcome now as I felt last year                    62661
# Somewhat more welcome now than last year                    8853
# A lot more welcome now than last year                       4808
# Somewhat less welcome now than last year                    4259
# Not applicable - I did not use Stack Overflow last year     2675
# A lot less welcome now than last year                       2599
# Name: WelcomeChange, dtype: int64

# %%
data['WelcomeChange'].value_counts().plot.bar()

# %%
salary_nepal = data['Country'] == 'Nepal'

# %%
salary_nepal
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %%
data.loc[: ,['Country', 'ConvertedComp']]
# Out:
#                       Country  ConvertedComp
# 0              United Kingdom            NaN
# 1      Bosnia and Herzegovina            NaN
# 2                    Thailand         8820.0
# 3               United States        61000.0
# 4                     Ukraine            NaN
# ...                       ...            ...
# 88878                  Canada            NaN
# 88879                     NaN            NaN
# 88880                     NaN            NaN
# 88881                     NaN            NaN
# 88882                   Spain            NaN
#
# [88883 rows x 2 columns]

# %%
salary_nepal = (data['Country'] == 'Nepal') & (data['ConvertedComp'] >10000)

# %%
data.loc[salary_nepal]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 5968         5993  I am a developer by profession      Yes
# 25114       25261  I am a developer by profession      Yes
# 25897       26047  I am a developer by profession       No
# 39282       39526  I am a developer by profession      Yes
# 40383       40634  I am a developer by profession      Yes
# 42801       43075  I am a developer by profession       No
# 54821       55169  I am a developer by profession      Yes
# 61281       61673  I am a developer by profession       No
# 63428       63835  I am a developer by profession      Yes
# 77455       77938  I am a developer by profession       No
# 78532       79024  I am a developer by profession      Yes
# 81604       82113  I am a developer by profession      Yes
# 84918       85446  I am a developer by profession      Yes
# 86082       86618  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
data.loc[salary_nepal,'Employment'].value_counts().plot.bar()

# %%
data.loc[salary_nepal,'Employment'].value_counts().plot.pie()

# %%
data_schema.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
data.loc[salary_nepal,['LanguageWorkedWith','ConvertedComp']]
# Out:
#                                       LanguageWorkedWith  ConvertedComp
# 5968                             HTML/CSS;JavaScript;PHP       300000.0
# 25114         C#;HTML/CSS;Java;JavaScript;PHP;Python;SQL        21096.0
# 25897                           HTML/CSS;JavaScript;Ruby        10545.0
# 39282  Assembly;C;C++;C#;HTML/CSS;Java;JavaScript;PHP...       100000.0
# 40383                     HTML/CSS;JavaScript;Python;SQL        10548.0
# 42801                                 JavaScript;PHP;SQL        30000.0
# 54821                     HTML/CSS;JavaScript;TypeScript        10548.0
# 61281              C#;HTML/CSS;JavaScript;SQL;TypeScript        12660.0
# 63428                         Java;JavaScript;TypeScript        12000.0
# 77455  Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...        12660.0
# 78532             HTML/CSS;Java;JavaScript;SQL;Other(s):        15818.0
# 81604  Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...        10548.0
# ...

# %%
#data.loc[(data['LanguageWorkedWith'] == 'JavaScript') & (data['ConvertedComp']> 1000)]

# %%
lang = data['LanguageWorkedWith']

# %%
lang
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
final_dataj = []
for java1 in lang:
  if java1 == 'Java':
    final_dataj.append(java1)

print(final_dataj)
print(len(final_dataj))
# Out:
# ['Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java', 'Java
# ...

# %%
final_datap = []
for py in lang:
  if py == 'Python':
    final_datap.append(py)

print(final_datap)
print(len(final_datap))
# Out:
# ['Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python', 'Python
# ...

# %%
final_dataj = []
for javas in lang:
  if javas == 'JavaScript':
    final_dataj.append(javas)

print(final_dataj)
print(len(final_dataj))
# Out:
# ['JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'JavaScript', 'Ja
# ...

# %%
data.loc[filt_nepal,['LanguageWorkedWith','ConvertedComp']]
# Out:
#                                       LanguageWorkedWith  ConvertedComp
# 506                            C;C++;HTML/CSS;JavaScript            NaN
# 589                        C;C++;HTML/CSS;PHP;Python;SQL            NaN
# 980                                     C++;Go;Other(s):        10000.0
# 1348             HTML/CSS;Java;JavaScript;SQL;TypeScript         3168.0
# 1775                                              Python         1692.0
# ...                                                  ...            ...
# 86082               HTML/CSS;Java;JavaScript;Python;Ruby        12000.0
# 86205                                                PHP            NaN
# 86691  Assembly;Bash/Shell/PowerShell;C;C++;Dart;HTML...            NaN
# 87026    C;C++;C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript         2640.0
# 87994                 HTML/CSS;JavaScript;PHP;Python;SQL            NaN
#
# [237 rows x 2 columns]

# %%
programming = data[data['LanguageWorkedWith'] == "Java"]

# %%
final_data = []
for java1 in data:
  if java1 == 'java':
    final_data.append(java1)

print(final_data)
# Out:
# []

# %%
data.loc[filt_nepal,'LanguageWorkedWith'].str.contains('java')
# Out:
# 506      False
# 589      False
# 980      False
# 1348     False
# 1775     False
#          ...
# 86082    False
# 86205    False
# 86691    False
# 87026    False
# 87994    False
# Name: LanguageWorkedWith, Length: 237, dtype: object

# %%
data.loc[filt_nepal,'LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    123
# True     101
# Name: LanguageWorkedWith, dtype: int64

# %%
data.loc[filt_nepal,'LanguageWorkedWith'].str.contains('Python')
# Out:
# 506      False
# 589       True
# 980      False
# 1348     False
# 1775      True
#          ...
# 86082     True
# 86205    False
# 86691     True
# 87026    False
# 87994     True
# Name: LanguageWorkedWith, Length: 237, dtype: object

# %%
#data.loc[filt_nepal,'LanguageWorkedWith'].str.contains('Python').notnulll()

# %%
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
 #data[data['Country'] == 'Nepal']

# %%
filt_nepal = data['Country'] == 'Nepal'

# %%
filt_nepal # display Series
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %%
data.loc[filt_nepal]  # dataframe
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %%
data_schema.loc['Respondent','QuestionText']
# Out:
# 'Randomized respondent ID number (not in order of survey response time)'

# %%
data_schema.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
data.loc[filt_nepal,'MgrIdiot']
# Out:
# 506                         NaN
# 589                         NaN
# 980          Somewhat confident
# 1348         Somewhat confident
# 1775       Not at all confident
#                   ...
# 86082      Not at all confident
# 86205        Somewhat confident
# 86691    I don't have a manager
# 87026        Somewhat confident
# 87994        Somewhat confident
# Name: MgrIdiot, Length: 237, dtype: object

# %%
data_schema.loc['LanguageWorkedWith', 'QuestionText']
# Out:
# 'Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
data.loc[filt_nepal,'LanguageWorkedWith'].str.contains('Python')
# Out:
# 506      False
# 589       True
# 980      False
# 1348     False
# 1775      True
#          ...
# 86082     True
# 86205    False
# 86691     True
# 87026    False
# 87994     True
# Name: LanguageWorkedWith, Length: 237, dtype: object

# %%
lst1= []
lst = ['java','javascript','python','ruby','math','advnace_java','java','java']
for i in lst:
  if i == "java": 
     lst1.append(i)
print(lst1)
print(len(lst1))
# Out:
# ['java', 'java', 'java']
# 3

# %%
data.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
data.SocialMedia
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
data[['SocialMedia']].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# dtype: int64

# %%
nepal = data[(data['Country'] == 'Nepal') & (data['SocialMedia'])]

# %%
country_group = data.groupby('Country')

# %%
country_group['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['Nepal']
# Out:
# SocialMedia
# YouTube                     95
# Facebook                    71
# LinkedIn                    22
# Twitter                     16
# Reddit                       9
# Instagram                    8
# WhatsApp                     5
# I don't use social media     4
# WeChat 微信                    1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['Nepal']
# Out:
# SocialMedia
# YouTube                     95
# Facebook                    71
# LinkedIn                    22
# Twitter                     16
# Reddit                       9
# Instagram                    8
# WhatsApp                     5
# I don't use social media     4
# WeChat 微信                    1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['Nepal'].plot.bar()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24494 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 24494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
country_group['Employment'].value_counts().loc['Nepal'].plot.bar()

# %%
social_group = data.groupby('SocialMedia')

# %%
social_group['SocialMedia'].value_counts()
# Out:
# SocialMedia               SocialMedia
# Facebook                  Facebook                    13178
# Hello                     Hello                          19
# I don't use social media  I don't use social media     5554
# Instagram                 Instagram                    6261
# LinkedIn                  LinkedIn                     4501
# Reddit                    Reddit                      14374
# Snapchat                  Snapchat                      628
# Twitter                   Twitter                     11398
# VK ВКонта́кте             VK ВКонта́кте                 603
# WeChat 微信                 WeChat 微信                     667
# Weibo 新浪微博                Weibo 新浪微博                     56
# WhatsApp                  WhatsApp                    13347
# YouTube                   YouTube                     13830
# Youku Tudou 优酷            Youku Tudou 优酷                 21
# Name: SocialMedia, dtype: int64

# %%
social_group['Country'].value_counts()
# Out:
# SocialMedia     Country
# Facebook        United States     2844
#                 India              841
#                 United Kingdom     811
#                 Poland             619
#                 Canada             515
#                                   ...
# Youku Tudou 优酷  Singapore            1
#                 Turkey               1
#                 Ukraine              1
#                 United Kingdom       1
#                 United States        1
# Name: Country, Length: 1220, dtype: int64

# %%
country_group['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_group['ConvertedComp'].median().loc['Nepal']
# Out:
# 4224.0

# %%
country_group['ConvertedComp'].agg(['mean','min', 'max'])
# Out:
#                                                mean       min        max
# Country
# Afghanistan                           101953.333333       0.0  1000000.0
# Albania                                21833.700000    1320.0   187668.0
# Algeria                                34924.047619       0.0  1000000.0
# Andorra                               160931.000000  150000.0   171862.0
# Angola                                  7764.000000    7764.0     7764.0
# ...                                             ...       ...        ...
# Venezuela, Bolivarian Republic of...   14581.627907       0.0   137484.0
# Viet Nam                               17233.436782     200.0   140000.0
# Yemen                                  16909.166667     799.0    60000.0
# Zambia                                 10075.375000     400.0    40524.0
# Zimbabwe                               34046.666667     900.0   180000.0
#
# [179 rows x 3 columns]

# %%
country_group['ConvertedComp'].agg(['mean','min', 'max', 'min']).loc['Nepal']
# Out:
# mean     10434.987952
# min          0.000000
# max     300000.000000
# min          0.000000
# Name: Nepal, dtype: float64

# %%
country_group['ConvertedComp'].agg(['mean','median','max','min']).loc['Nepal']
# Out:
# mean       10434.987952
# median      4224.000000
# max       300000.000000
# min            0.000000
# Name: Nepal, dtype: float64

# %%
country_group['LanguageWorkedWith'].value_counts()
# Out:
# Country      LanguageWorkedWith
# Afghanistan  HTML/CSS;JavaScript;PHP;SQL                3
#              HTML/CSS;Java;JavaScript;PHP;Python;SQL    2
#              HTML/CSS;Java;PHP;SQL                      2
#              Python                                     2
#              Assembly                                   1
#                                                        ..
# Zimbabwe     HTML/CSS;Python;SQL                        1
#              Java;JavaScript;Kotlin;Python              1
#              Java;JavaScript;SQL                        1
#              Objective-C                                1
#              Python                                     1
# Name: LanguageWorkedWith, Length: 48114, dtype: int64

# %%
country_group['LanguageWorkedWith'].value_counts().loc['Nepal']
# Out:
# LanguageWorkedWith
# HTML/CSS;JavaScript;PHP        10
# HTML/CSS;JavaScript;PHP;SQL     6
# HTML/CSS;JavaScript             5
# PHP                             5
# Python                          5
#                                ..
# JavaScript;Python;SQL           1
# JavaScript;TypeScript           1
# PHP;Ruby                        1
# Python;Ruby                     1
# R                               1
# Name: LanguageWorkedWith, Length: 174, dtype: int64

# %%
country_uses_python = country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_data = pd.concat([country_total,country_uses_python], axis='columns')
python_data

# %%
python_data.rename(columns={'Country':'TotalDevelopers','LanguageWorkedWith':'KnowsPython'}, inplace=True)
python_data

# %%
python_data.rename(columns={'Country':'TotalDevelopers','LanguageWorkedWith':'KnowsPython'}, inplace=True)
python_df
