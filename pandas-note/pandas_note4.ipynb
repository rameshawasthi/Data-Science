# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/ML_AI/DATASETS/survey_results_public.csv")

# %%
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
data[['OpenSource','Employment','Country']]
# Out:
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# ...

# %%
data[['OpenSource']]
# Out:
#                                               OpenSource
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# [88883 rows x 1 columns]

# %%
data[['OpenSource','Employment','Country']] [:10]
# Out:
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
# 6  The quality of OSS and closed source software ...
# 7  OSS is, on average, of HIGHER quality than pro...
# 8  The quality of OSS and closed source software ...
# 9  OSS is, on average, of HIGHER quality than pro...
#
#                                           Employment                 Country
# 0             Not employed, and not looking for work          United Kingdom
# 1                 Not employed, but looking for work  Bosnia and Herzegovina
# 2                                 Employed full-time                Thailand
# ...

# %%
data[['Country','Employment']].value_counts()
# Out:
# Country         Employment
# United States   Employed full-time                                      16771
# India           Employed full-time                                       6613
# United Kingdom  Employed full-time                                       4458
# Germany         Employed full-time                                       4182
# Canada          Employed full-time                                       2493
#                                                                         ...
# Guinea          Employed full-time                                          1
#                 Employed part-time                                          1
#                 Independent contractor, freelancer, or self-employed        1
# Guyana          Employed full-time                                          1
# Zimbabwe        Retired                                                     1
# Length: 780, dtype: int64

# %%
country_count = data['Country'].value_counts()
country_count[:11]
# Out:
# United States         20949
# India                  9061
# Germany                5866
# United Kingdom         5737
# Canada                 3395
# France                 2391
# Brazil                 1948
# Poland                 1922
# Australia              1903
# Netherlands            1852
# Russian Federation     1694
# Name: Country, dtype: int64

# %%
country_count[:11].plot.bar()

# %%
country_count
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
data[:5]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
Not_employed = data[data['Employment'] == "Not employed, and not looking for work"]
Not_employed[:4]
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 0            1  I am a student who is learning to code      Yes
# 30          31  I am a student who is learning to code       No
# 87          88             I code primarily as a hobby      Yes
# 88          89  I am a student who is learning to code      Yes
#
#                                           OpenSourcer  \
# 0                                               Never
# 30                                              Never
# 87  Less than once a month but more than once per ...
# 88                                              Never
#
#                                            OpenSource  \
# 0   The quality of OSS and closed source software ...
# 30                                                NaN
# 87  The quality of OSS and closed source software ...
# 88  OSS is, on average, of HIGHER quality than pro...
#
#                                 Employment         Country Student  \
# ...

# %%
Not_employed = data [data['Employment'] == "Not employed, and not looking for work"]
Not_employed
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 30             31  I am a student who is learning to code       No
# 87             88             I code primarily as a hobby      Yes
# 88             89  I am a student who is learning to code      Yes
# 202           204  I am a student who is learning to code      Yes
# ...           ...                                     ...      ...
# 88866       86638                                     NaN      Yes
# 88869       86999                                     NaN       No
# 88870       87352                                     NaN      Yes
# 88878       88377                                     NaN      Yes
# 88882       88863                                     NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
emp=data['Employment']== "Not employed, and not looking for work"
cn=data['Country']== "Nepal"
data[emp & cn ] [:5]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 5239         5262          I am a developer by profession      Yes
# 16696       16786  I am a student who is learning to code      Yes
# 19085       19189  I am a student who is learning to code      Yes
# 19210       19315  I am a student who is learning to code      Yes
# 21002       21118  I am a student who is learning to code       No
#
#                       OpenSourcer  \
# 5239   Once a month or more often
# 16696                       Never
# 19085                       Never
# 19210  Once a month or more often
# 21002  Once a month or more often
#
#                                               OpenSource  \
# 5239   OSS is, on average, of LOWER quality than prop...
# 16696  OSS is, on average, of HIGHER quality than pro...
# 19085  The quality of OSS and closed source software ...
# 19210  OSS is, on average, of HIGHER quality than pro...
# 21002  OSS is, on average, of HIGHER quality than pro...
#
# ...
