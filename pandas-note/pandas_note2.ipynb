# %%
import pandas as pd

# %%
#Read the Csv file and convert it Dataframe
df = pd.read_csv("/content/drive/MyDrive/ML_AI/DATASETS/ds_salaries.csv",)

# %%
df.head(3)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M

# %%
df.index
# Out:
# RangeIndex(start=0, stop=607, step=1)

# %%
df[["Unnamed: 0" ]]
# Out:
#      Unnamed: 0
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 602         602
# 603         603
# 604         604
# 605         605
# 606         606
#
# [607 rows x 1 columns]

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
#Print the shape and info of the dataframe
df.shape
# Out:
# (607, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %%
#List out the name of the columns
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
#Find the mean salary of all people.
df['salary_in_usd'].mean()
# Out:
# 112297.86985172982

# %%
#using the value_counts(), list the jobs different titles.

df['job_title'].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
df['job_title'].value_counts().plot.bar()

# %%
#show the different between loc and iloc .
df.loc[:,['work_year','employment_type','employment_type']]
# Out:
#      work_year employment_type employment_type
# 0         2020              FT              FT
# 1         2020              FT              FT
# 2         2020              FT              FT
# 3         2020              FT              FT
# 4         2020              FT              FT
# ..         ...             ...             ...
# 602       2022              FT              FT
# 603       2022              FT              FT
# 604       2022              FT              FT
# 605       2022              FT              FT
# 606       2022              FT              FT
#
# [607 rows x 3 columns]

# %%
df.loc[1:5,['work_year', 'employment_type', 'salary']]
# Out:
#    work_year employment_type  salary
# 1       2020              FT  260000
# 2       2020              FT   85000
# 3       2020              FT   20000
# 4       2020              FT  150000
# 5       2020              FT   72000

# %%
df.columns.value_counts()
# Out:
# work_year             1
# experience_level      1
# employment_type       1
# job_title             1
# salary                1
# salary_currency       1
# salary_in_usd         1
# employee_residence    1
# remote_ratio          1
# company_location      1
# company_size          1
# dtype: int64

# %%
#display zero row salary
df.loc[0,'salary']
# Out:
# 70000

# %%
#Display  range from zero to five rows, and column "salary" and "salary_currency" 
df.loc[0:5, ["salary","salary_currency",'salary_in_usd']]
# Out:
#    salary salary_currency  salary_in_usd
# 0   70000             EUR          79833
# 1  260000             USD         260000
# 2   85000             GBP         109024
# 3   20000             USD          20000
# 4  150000             USD         150000
# 5   72000             USD          72000

# %%
df.iloc[3:10]
# Out:
#    work_year experience_level employment_type                  job_title  \
# 3       2020               MI              FT       Product Data Analyst
# 4       2020               SE              FT  Machine Learning Engineer
# 5       2020               EN              FT               Data Analyst
# 6       2020               SE              FT        Lead Data Scientist
# 7       2020               MI              FT             Data Scientist
# 8       2020               MI              FT      Business Data Analyst
# 9       2020               SE              FT         Lead Data Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3     20000             USD          20000                 HN             0
# 4    150000             USD         150000                 US            50
# 5     72000             USD          72000                 US           100
# 6    190000             USD         190000                 US           100
# ...

# %%
#display zero row. 
#df.iloc[0]
df.iloc[[0]]
# Out:
#    work_year experience_level employment_type       job_title  salary  \
# 0       2020               MI              FT  Data Scientist   70000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          79833                 DE             0
#
#   company_location company_size
# 0               DE            L

# %%
# Selecting disparate rows in the necessary order
df.iloc[[4, 3, 2]]
# Out:
#    work_year experience_level employment_type                  job_title  \
# 4       2020               SE              FT  Machine Learning Engineer
# 3       2020               MI              FT       Product Data Analyst
# 2       2020               SE              FT          Big Data Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 4  150000             USD         150000                 US            50
# 3   20000             USD          20000                 HN             0
# 2   85000             GBP         109024                 GB            50
#
#   company_location company_size
# 4               US            L
# 3               HN            S
# 2               GB            M

# %%
# Selecting a slice of sequential rows
df.iloc[3:6]
# Out:
#    work_year experience_level employment_type                  job_title  \
# 3       2020               MI              FT       Product Data Analyst
# 4       2020               SE              FT  Machine Learning Engineer
# 5       2020               EN              FT               Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
# 5   72000             USD          72000                 US           100
#
#   company_location company_size
# 3               HN            S
# 4               US            L
# 5               US            L

# %%
# Selecting a slice of sequential rows (an open-ending range)
df.iloc[:4]
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S

# %%
# Selecting an individual data point
df.iloc[1, 3]
# Out:
# 'Machine Learning Scientist'

# %%
# Selecting one row and multiple disparate columns
df.iloc[0, [2, 8, 3]]
# Out:
# employment_type                FT
# remote_ratio                    0
# job_title          Data Scientist
# Name: 0, dtype: object

# %%
# Selecting multiple disparate rows and multiple sequential columns
df.iloc[[8, 10, 9], 5:9]
# Out:
#    salary_currency  salary_in_usd employee_residence  remote_ratio
# 8              USD         135000                 US           100
# 10             EUR          51321                 FR             0
# 9              USD         125000                 NZ            50

# %%
# Selecting multiple sequential rows and multiple sequential columns (with open-ending ranges)
df.iloc[:3, 6:]
# Out:
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833                 DE             0               DE
# 1         260000                 JP             0               JP
# 2         109024                 GB            50               GB
#
#   company_size
# 0            L
# 1            S
# 2            M

# %%
# Selecting all rows and multiple disparate columns
df.iloc[:, [1, 3, 7]]
# Out:
#     experience_level                   job_title employee_residence
# 0                 MI              Data Scientist                 DE
# 1                 SE  Machine Learning Scientist                 JP
# 2                 SE           Big Data Engineer                 GB
# 3                 MI        Product Data Analyst                 HN
# 4                 SE   Machine Learning Engineer                 US
# ..               ...                         ...                ...
# 602               SE               Data Engineer                 US
# 603               SE               Data Engineer                 US
# 604               SE                Data Analyst                 US
# 605               SE                Data Analyst                 US
# 606               MI                AI Scientist                 IN
#
# [607 rows x 3 columns]

# %%
df.iloc[1:3, 5]
# Out:
# 1    USD
# 2    GBP
# Name: salary_currency, dtype: object

# %%
df.iloc[-5:]
# Out:
#      work_year experience_level employment_type      job_title  salary  \
# 602       2022               SE              FT  Data Engineer  154000
# 603       2022               SE              FT  Data Engineer  126000
# 604       2022               SE              FT   Data Analyst  129000
# 605       2022               SE              FT   Data Analyst  150000
# 606       2022               MI              FT   AI Scientist  200000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602             USD         154000                 US           100
# 603             USD         126000                 US           100
# 604             USD         129000                 US             0
# 605             USD         150000                 US           100
# 606             USD         200000                 IN           100
#
#     company_location company_size
# 602               US            M
# 603               US            M
# ...

# %%
#filter People with salaries greater than 100000 USD
#df.columns

df[(df['salary'] > 10000)]
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
#perform  values counts in the above group of people  based on job title.
df.columns
sly = df.groupby('salary')

# %%
sly['job_title'].value_counts()
# Out:
# salary    job_title
# 4000      Data Engineer      1
#           Data Scientist     1
# 8000      Data Analyst       1
# 8760      Data Analyst       1
# 9272      BI Data Analyst    1
#                             ..
# 7000000   ML Engineer        1
# 8500000   ML Engineer        1
# 11000000  BI Data Analyst    1
#           Data Scientist     1
# 30400000  Data Scientist     1
# Name: job_title, Length: 458, dtype: int64

# %%
#Perform double filtration: Based on job_title "Data Scientist" and residence "US" Retrieve the list of their salaries.

job = df.groupby('job_title')

# %%
data= df.loc[(df['job_title'] == 'Data Scientist') & (df['employee_residence'] == 'US')]

# %%
data
# Out:
#      work_year experience_level employment_type       job_title  salary  \
# 48        2020               MI              FT  Data Scientist  105000
# 57        2020               MI              FT  Data Scientist  118000
# 58        2020               SE              FT  Data Scientist  120000
# 59        2020               MI              FT  Data Scientist  138350
# 63        2020               SE              FT  Data Scientist  412000
# ..         ...              ...             ...             ...     ...
# 592       2022               SE              FT  Data Scientist  230000
# 593       2022               SE              FT  Data Scientist  150000
# 596       2022               SE              FT  Data Scientist  210000
# 598       2022               MI              FT  Data Scientist  160000
# 599       2022               MI              FT  Data Scientist  130000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...
