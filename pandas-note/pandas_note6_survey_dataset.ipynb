# %% [markdown]
# Introduction:
#
# > Indented block
#
#
# **Pandas library of python is very useful for the manipulation of mathematical,data and is widely used in the field of machine learning for data analysis.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Import Pandas package
import pandas as pd

# %% [markdown]
# # Creating, Reading and Writing
# 1.Creating:
# In Pandas there are two object
#   i) DataFrame:a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns. use DataFrame() function.
#
#    note: DataFrame entries are not for only integers also for instance.
#
#   ii)Series:A series is a sequence of data. It is list we can create  list only.
#       A Series is, in essence, a single column of a DataFrame. So you can     assign row labels to the Series the same way as before, using an index parameter. However, a Series does not have a column name, it only has one overall name.

# %%
pd.DataFrame({'quantity' : [10,12], 'price': [1200,1400]})
# Out:
#    quantity  price
# 0        10   1200
# 1        12   1400

# %%
pd.DataFrame({'Nepal' : ['nepal is','beautiful', 'country.'], 'Kathmandu' : ['Kathmandu is','capital','of nepal']})
# Out:
#        Nepal     Kathmandu
# 0   nepal is  Kathmandu is
# 1  beautiful       capital
# 2   country.      of nepal

# %%
#The list of row labels used in a DataFrame is known as an Index.

pd.DataFrame({'Nepal' : ['nepal is','beautiful', 'country.'], 'Kathmandu' : ['Kathmandu is','capital','of nepal']},
               index=['A', 'B','c'])
# Out:
#        Nepal     Kathmandu
# A   nepal is  Kathmandu is
# B  beautiful       capital
# c   country.      of nepal

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([3000, 3500, 4000], index=['2021 price', '2020 price', '2019 price'], name='Index A')
# Out:
# 2021 price    3000
# 2020 price    3500
# 2019 price    4000
# Name: Index A, dtype: int64

# %% [markdown]
# **Reading:**
# pd.read_csv('Your file path')

# %%
data = pd.read_csv("/content/drive/MyDrive/ML_AI/DATASETS/survey_results_public.csv")
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=88883, step=1)

# %%
data.shape
# Out:
# (88883, 85)

# %%
data.size
# Out:
# 7555055

# %% [markdown]
# **iloc[]**

# %%
#display zero row. 
#data.iloc[0]
data.iloc[[0]]
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel UndergradMajor  ...  \
# 0  Primary/elementary school            NaN  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SurveyEase
# 0  Neither easy nor difficult
#
# ...

# %%
# Selecting disparate rows in the necessary order
data.iloc[[4, 3, 2]]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 4           5                     I am a developer by profession      Yes
# 3           4                     I am a developer by profession       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                   OpenSourcer  \
# 4  Once a month or more often
# 3                       Never
# 2                       Never
#
#                                           OpenSource          Employment  \
# 4  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 2  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                   EdLevel  \
# 4        Ukraine      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
# Selecting a slice of sequential rows
data.iloc[3:6]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
#
#                   OpenSourcer  \
# 3                       Never
# 4  Once a month or more often
# 5                       Never
#
#                                           OpenSource          Employment  \
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 5  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                   EdLevel  \
# 3  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4        Ukraine      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
# Selecting a slice of sequential rows (an open-ending range)
data.iloc[:4]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
# 3                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# ...

# %%
# Selecting an individual data point
data.iloc[1, 3]
# Out:
# 'Less than once per year'

# %%
# Selecting one row and multiple disparate columns
data.iloc[0, [2, 8, 3]]
# Out:
# Hobbyist                             Yes
# EdLevel        Primary/elementary school
# OpenSourcer                        Never
# Name: 0, dtype: object

# %%
# Selecting multiple disparate rows and multiple sequential columns
data.iloc[[8, 10, 9], 5:9]
# Out:
#             Employment              Country         Student  \
# 8   Employed full-time          New Zealand              No
# 10                 NaN  Antigua and Barbuda  Yes, full-time
# 9   Employed full-time                India              No
#
#                                               EdLevel
# 8   Some college/university study without earning ...
# 10                          Primary/elementary school
# 9         Master’s degree (MA, MS, M.Eng., MBA, etc.)

# %%
# Selecting multiple sequential rows and multiple sequential columns (with open-ending ranges)
data.iloc[:3, 6:]
# Out:
#                   Country         Student  \
# 0          United Kingdom              No
# 1  Bosnia and Herzegovina  Yes, full-time
# 2                Thailand              No
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1  Secondary school (e.g. American high school, G...
# 2           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                   UndergradMajor  \
# 0                            NaN
# 1                            NaN
# 2  Web development or web design
#
#                                             EduOther               OrgSize  \
# 0  Taught yourself a new language, framework, or ...                   NaN
# 1  Taken an online course in programming or softw...                   NaN
# 2  Taught yourself a new language, framework, or ...  100 to 499 employees
#
#                                              DevType YearsCode Age1stCode  \
# ...

# %%
# Selecting all rows and multiple disparate columns
data.iloc[:, [1, 3, 7]]
# Out:
#                                               MainBranch  \
# 0                 I am a student who is learning to code
# 1                 I am a student who is learning to code
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                              OpenSourcer         Student
# 0                                                  Never              No
# 1                                Less than once per year  Yes, full-time
# ...

# %%
data.iloc[1:3, 1]
# Out:
# 1               I am a student who is learning to code
# 2    I am not primarily a developer, but I write co...
# Name: MainBranch, dtype: object

# %%
data.iloc[2,5:10]
# Out:
# Employment                              Employed full-time
# Country                                           Thailand
# Student                                                 No
# EdLevel           Bachelor’s degree (BA, BS, B.Eng., etc.)
# UndergradMajor               Web development or web design
# Name: 2, dtype: object

# %%
data.iloc[-5:]
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %% [markdown]
# **iat Indexer**
# To select only one value from a dataframe, we can use the iat indexer, which performs faster than iloc. The syntax is identical to the one of the iloc indexer, only that here we always use exactly two integers (the row and column position numbers):

# %%
data.iat[0, 0]
# Out:
# 1

# %%
#display specific column
data["Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
#display specific column with column name
data[["Hobbyist"]]
# Out:
#       Hobbyist
# 0          Yes
# 1           No
# 2          Yes
# 3           No
# 4          Yes
# ...        ...
# 88878      Yes
# 88879       No
# 88880       No
# 88881       No
# 88882      Yes
#
# [88883 rows x 1 columns]

# %%
#Display "Hobbyist" toal values
data["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
#display index zero row and column two
data.iloc[0,2]
# Out:
# 'Yes'

# %% [markdown]
# **II): label-based selection**
# The second paradigm for attribute selection is the one followed by the loc operator: label-based selection. In this paradigm, it's the data index value, not its position, which matters.

# %%
data[['Hobbyist', 'OpenSourcer', 'Country']]
# Out:
#       Hobbyist                                        OpenSourcer  \
# 0          Yes                                              Never
# 1           No                            Less than once per year
# 2          Yes                                              Never
# 3           No                                              Never
# 4          Yes                         Once a month or more often
# ...        ...                                                ...
# 88878      Yes  Less than once a month but more than once per ...
# 88879       No                                              Never
# 88880       No                                              Never
# 88881       No                                              Never
# 88882      Yes                            Less than once per year
#
#                       Country
# 0              United Kingdom
# 1      Bosnia and Herzegovina
# 2                    Thailand
# 3               United States
# ...

# %%
data.loc[1:5,['Hobbyist', 'OpenSourcer', 'Country']]
# Out:
#   Hobbyist                 OpenSourcer                 Country
# 1       No     Less than once per year  Bosnia and Herzegovina
# 2      Yes                       Never                Thailand
# 3       No                       Never           United States
# 4      Yes  Once a month or more often                 Ukraine
# 5      Yes                       Never                  Canada

# %%
data.columns.value_counts()
# Out:
# Respondent        1
# OpSys             1
# Extraversion      1
# SocialMedia       1
# OffOn             1
#                  ..
# CurrencySymbol    1
# ResumeUpdate      1
# JobFactors        1
# FizzBuzz          1
# SurveyEase        1
# Length: 85, dtype: int64

# %%
#display zero row Hobyyist 
data.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
#Display  range from zero to five rows, and column "Hobbyist" and "OpenSourcer" 
data.loc[0:5, ["Hobbyist","OpenSourcer"]]
# Out:
#   Hobbyist                 OpenSourcer
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
# 5      Yes                       Never

# %%
#data.loc[10:15,'Hobbyist':'Employment']

# %%
#data['Country'] == 'Nepal'

# %%
#(data['Country'] == 'Nepal').value_counts()

# %%
 #data[data['Country'] == 'Nepal']

# %%
filt_nepal = data['Country'] == 'Nepal'

data.loc[filt_nepal]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %%
filt_nepal = data['Country'] == 'Nepal'

nepal = data.loc[filt_nepal]
nepal.head()
# Out:
#       Respondent                              MainBranch Hobbyist  \
# 506          508  I am a student who is learning to code      Yes
# 589          592          I am a developer by profession      Yes
# 980          984          I am a developer by profession      Yes
# 1348        1355          I am a developer by profession      Yes
# 1775        1783          I am a developer by profession      Yes
#
#                                             OpenSourcer  \
# 506                                               Never
# 589                                               Never
# 980                                               Never
# 1348                                              Never
# 1775  Less than once a month but more than once per ...
#
#                                              OpenSource  \
# 506   OSS is, on average, of LOWER quality than prop...
# 589   OSS is, on average, of LOWER quality than prop...
# ...

# %%
data_schema = pd.read_csv("/content/drive/MyDrive/ML_AI/DATASETS/survey_results_schema.csv", index_col="Column")

# %%
data_schema.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
data_schema.loc['Respondent','QuestionText']
# Out:
# 'Randomized respondent ID number (not in order of survey response time)'

# %%
data_schema.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
data.loc[filt_nepal,'MgrIdiot'].value_counts()
# Out:
# Somewhat confident        66
# Very confident            28
# Not at all confident      23
# I don't have a manager     9
# Name: MgrIdiot, dtype: int64

# %%
data.loc[filt_nepal,'MgrIdiot'].value_counts().plot.bar()

# %%
data.loc[filt_nepal,'MgrIdiot'].value_counts().plot.pie()

# %%
filt_idiot = data[(data['Country'] == 'Nepal') & (data['MgrIdiot'] == 'Not at all confident')] 
filt_idiot
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 1775         1783  I am a developer by profession      Yes
# 4431         4452  I am a developer by profession      Yes
# 8354         8392  I am a developer by profession       No
# 8713         8751  I am a developer by profession      Yes
# 9819         9860  I am a developer by profession      Yes
# 12165       12222  I am a developer by profession      Yes
# 16410       16498  I am a developer by profession      Yes
# 25834       25984  I am a developer by profession      Yes
# 28988       29157  I am a developer by profession      Yes
# 32415       32610  I am a developer by profession      Yes
# 40357       40608  I am a developer by profession      Yes
# 40855       41114  I am a developer by profession      Yes
# 51711       52045  I am a developer by profession      Yes
# 60109       60493  I am a developer by profession      Yes
# 60774       61164     I code primarily as a hobby      Yes
# ...

# %%
data_schema[filt_idiot]
# Out:
#              QuestionText
# Column
# Respondent            NaN
# MainBranch            NaN
# Hobbyist              NaN
# OpenSourcer           NaN
# OpenSource            NaN
# ...                   ...
# Sexuality             NaN
# Ethnicity             NaN
# Dependents            NaN
# SurveyLength          NaN
# SurveyEase            NaN
#
# [85 rows x 1 columns]

# %%
data_schema.loc['ConvertedComp']
# Out:
# QuestionText    Salary converted to annual USD salaries using ...
# Name: ConvertedComp, dtype: object

# %%
data_schema.loc['ConvertedComp','QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.'

# %%
data.loc[filt_nepal,'ConvertedComp']
# Out:
# 506          NaN
# 589          NaN
# 980      10000.0
# 1348      3168.0
# 1775      1692.0
#           ...
# 86082    12000.0
# 86205        NaN
# 86691        NaN
# 87026     2640.0
# 87994        NaN
# Name: ConvertedComp, Length: 237, dtype: float64

# %%
data_schema.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
data_schema.iloc[0]
# Out:
# QuestionText    Randomized respondent ID number (not in order ...
# Name: Respondent, dtype: object

# %%
data_schema.sort_index()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
data_schema.sort_index(ascending=False)
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
data.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
#data[data['Country'] == 'Nepal']
data.Country
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
 data[data['Country'] == 'Nepal']
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %%
nepal= data.loc[data['Country']=='Nepal']

# %%
#data[['UndergradMajor']]

# %%
eng_data = data.loc[(data['Country'] == 'Nepal') & (data['UndergradMajor'] == 'Computer science, computer engineering, or software engineering')]
eng_data
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 589           592  I am a developer by profession      Yes
# 980           984  I am a developer by profession      Yes
# 1348         1355  I am a developer by profession      Yes
# 1775         1783  I am a developer by profession      Yes
# 1888         1896  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 84918       85446  I am a developer by profession      Yes
# 86082       86618  I am a developer by profession      Yes
# 86691       87231  I am a developer by profession      Yes
# 87026       87568  I am a developer by profession      Yes
# 87994       88543  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 589                                                Never
# 980                                                Never
# 1348                                               Never
# ...

# %%
data[(data['Country'] == 'Nepal') & (data['UndergradMajor'] == 'Computer science, computer engineering, or software engineering')]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 589           592  I am a developer by profession      Yes
# 980           984  I am a developer by profession      Yes
# 1348         1355  I am a developer by profession      Yes
# 1775         1783  I am a developer by profession      Yes
# 1888         1896  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 84918       85446  I am a developer by profession      Yes
# 86082       86618  I am a developer by profession      Yes
# 86691       87231  I am a developer by profession      Yes
# 87026       87568  I am a developer by profession      Yes
# 87994       88543  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 589                                                Never
# 980                                                Never
# 1348                                               Never
# ...

# %%
(data['Country'] == 'Nepal') & (data['UndergradMajor'] == 'Computer science, computer engineering, or software engineering')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Length: 88883, dtype: bool

# %%
data.OpenSource
# Out:
# 0        The quality of OSS and closed source software ...
# 1        The quality of OSS and closed source software ...
# 2        The quality of OSS and closed source software ...
# 3        The quality of OSS and closed source software ...
# 4        OSS is, on average, of HIGHER quality than pro...
#                                ...
# 88878    The quality of OSS and closed source software ...
# 88879    The quality of OSS and closed source software ...
# 88880                                                  NaN
# 88881    OSS is, on average, of HIGHER quality than pro...
# 88882    OSS is, on average, of HIGHER quality than pro...
# Name: OpenSource, Length: 88883, dtype: object
